# %%
from sympy import * 
from math import pi
r, D ,H1 ,H3, n,Q0 = symbols('r D H1 H3 n Q0')
E,H1, S, L1, L3, a ,M,Q= symbols('E H1 S L1 L3 a M Q')
solve([ Eq( r,3.14*D/H3 ),Eq( Q0, (n(3.14*D))**2/(H3)**2 ) ,Eq(r,93),
      
      Eq(E,3), Eq(E,(D-H1)*H1 /((D-H3)*H3) )
    , Eq(L3,72*D*H3**3/(Q*n))  
      
      ] , {  D ,H1 ,H3,  Q0,E,Q,r,n} )
# Out:
# [{r: 93.0000000000000,
#   D: -4.35844782340698*I*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: -46.1788271444081*n(-13.6855261654979*I*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: -1.69995996927186*sqrt(-(L3*Q*n)**0.5) - 2.17922391170349*I*(L3*Q*n)**(1/4),
#   H3: -0.147156195327935*I*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: -4.35844782340698*I*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: -46.1788271444081*n(-13.6855261654979*I*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: 1.69995996927186*sqrt(-(L3*Q*n)**0.5) - 2.17922391170349*I*(L3*Q*n)**(1/4),
#   H3: -0.147156195327935*I*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: 4.35844782340698*I*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: -46.1788271444081*n(13.6855261654979*I*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: -1.69995996927186*sqrt(-(L3*Q*n)**0.5) + 2.17922391170349*I*(L3*Q*n)**(1/4),
#   H3: 0.147156195327935*I*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: 4.35844782340698*I*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: -46.1788271444081*n(13.6855261654979*I*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: 1.69995996927186*sqrt(-(L3*Q*n)**0.5) + 2.17922391170349*I*(L3*Q*n)**(1/4),
#   H3: 0.147156195327935*I*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: -4.35844782340698*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: 46.1788271444081*n(-13.6855261654979*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: -3.87918388097535*(L3*Q*n)**(1/4),
#   H3: -0.147156195327935*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: -4.35844782340698*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: 46.1788271444081*n(-13.6855261654979*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: -0.479263942431633*(L3*Q*n)**(1/4),
#   H3: -0.147156195327935*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: 4.35844782340698*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: 46.1788271444081*n(13.6855261654979*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: 0.479263942431633*(L3*Q*n)**(1/4),
#   H3: 0.147156195327935*(L3*Q*n)**(1/4)},
#  {r: 93.0000000000000,
#   D: 4.35844782340698*(L3*Q*n)**(1/4),
#   E: 3.00000000000000,
#   Q0: 46.1788271444081*n(13.6855261654979*(L3*Q*n)**(1/4))**2/sqrt(L3*Q*n),
#   H1: 3.87918388097535*(L3*Q*n)**(1/4),
#   H3: 0.147156195327935*(L3*Q*n)**(1/4)}]
