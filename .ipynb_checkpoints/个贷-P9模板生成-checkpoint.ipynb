# %%
import pandas as pd
import numpy as np
from xlrd import open_workbook
import xlwt

 

DbAccess_id = "app_gdfhts_vt"
p2_outfile='#PATH_HOME#/file/output/p9000/AB371/371000000/data/#par_date#/P9000_SAFEID_371000000_%s_ADD_#par_date#_0001.dat'
b_tar_path='/home/ap/dip/file/input/AB371/371000000/data/#par_date#/P9000_SAFEID_371000000_%s_ADD_#par_date#_0001.dat'

P9_Template_XLS_ = r"E:\资料\个贷配套改造项目\P9工作配置模板.xlsx"
P9_Task_XLS = r"E:\资料\个贷配套改造项目\P9工作配置_工作.xlsx"
template_title = 0
template_taskFlow = 1
template_taskFlowDepend = 2
template_task = 3
template_taskParams = 4
template_taskDepend = 5
lists = [ ['BF_AGT_LOAN_ARRANGEMENT','AR_借款合同基本信息表','ARDAT_LOANARRANGEMENT','T0202_ARDAT_LOANARRA_0_H_371']
,['BF_AGT_LOAN_AUTODEBIT','AR_借款合同委托扣款账户','ARDAT_AUTODEBIT','T0202_ARDAT_AUTODEBI_0_H_371']
,['BF_AGT_COND_OF_CONTRACT','AR_借款合同条件信息','ARDAT_CONDOFCONTRACT','T0202_ARDAT_CONDOFCO_0_H_371']
,['BF_AGT_CORP_ARRANGEMENT','AR_合作协议','ARDAT_CORPARRANGEMENT','T0202_ARDAT_CORPARRA_0_H_371']
,['BF_AGT_CORPFUND','AR_合作方协议补充信息','ARDAT_CORPFUND','T0202_ARDAT_CORPFUND_0_H_371']
,['BF_AGT_CORP_PROJECT','AR_合作项目','ARDAT_CORPPROJECT','T0202_ARDAT_CORPPROJ_0_H_371']
,['BF_AGT_CREDIT_LOAN_ARRANGEMENT','AR_额度贷款合同基本信息表','ARDAT_CREDITLOANARRANGEMENT','T0202_ARDAT_CREDITLO_0_H_371']
,['BF_AGT_EVALUATEOF_RISK','AR_合约评价信息表_风险等级','ARDAT_EVALUATEOFRISK','T0202_ARDAT_EVALUATE_0_H_371']
,['BF_AGT_FUND_LOAN_COMPINFOREGI','AR_公积金贷款补充信息登记表','ARDAT_FUNDLOANCOMPINFOREGI','T0202_ARDAT_FUNDLOAN_0_H_371']
,['BF_AGT_GUARANTEE','AR_担保合同表','ARDAT_GUARANTEE','T0202_ARDAT_GUARANTE_0_H_371']
,['BF_AGT_LOAN_ACCT_INFO','AR_贷款账户信息','ARDAT_LOANACCTINFO','T0202_ARDAT_LOANACCT_0_H_371']
,['BF_AGT_MASTR_SLAVE_RELA','AR_主从合同对照表','ARDAT_MASTERSLAVERELA','T0202_ARDAT_MASTERSL_0_H_371']
,['BF_AGT_BILLPLAN','AR_账单计划','ARDAT_BILLPLAN','T0202_ARDAT_BILLPLAN_A_371','1']
,['BF_AGT_STUDENT_LOAN','AR_助学贷款','ARDAT_STUDENTLOAN','T0202_ARDAT_STUDENTL_0_H_371']
,['BF_EVT_LOAN_FLOW_REGI','EV_贷款流程意见登记表','EVDAT_LOANFLOWREGI','T0202_EVDAT_LOANFLOW_1_H_371']
,['BF_EVT_RISK_SORT_RESULT','EV_风险分类当前结果表','EVDAT_RISKSORTRESULT','T0202_EVDAT_RISKSORT_3_H_371']
,['BF_CM_ADDRESS_INFO','LO_地址信息主表','LODAT_ADDRESSINFO','T0202_LODAT_ADDRESSI_0_H']
,['BF_AST_ACCT_INFO','RI_银行存款','RIDAT_ACCTINFO','T0202_RIDAT_ACCTINFO_0_H']
,['BF_AST_BUIL_BASE_INFO','RI_楼盘基本信息','RIDAT_BUILBASEINFO','T0202_RIDAT_BUILBASE_0_H_371']
,['BF_AST_BUIL_PROJ_INFO','RI_楼盘项目信息','RIDAT_BUILPROJINFO','T0202_RIDAT_BUILPROJ_0_H_371']
,['BF_AST_HOUSE_BASE_INFO','RI_房屋基本信息表','RIDAT_HOUSEBASEINFO','T0202_RIDAT_HOUSEBAS_0_H']
,['BF_AST_RIINFOMAIN','RI_资源信息主表','RIDAT_RIINFOMAIN','T0202_RIDAT_RIINFOMA_0_H_371']
,['BF_PR_NPLPM_CUST_INFO','IP_客户信息主表','IPDAT_CUSTINFO','T0202_IPDAT_CUSTINFO_H']
,['BF_PRD_CUSTADDRINFO','IP_客户与地址关系表','IPDAT_CUSTADDRINFO','T0202_IPDAT_CUSTADDRI0_H']
,['BF_PRD_PERSCUSTINFO','IP_个人客户基本信息表','IPDAT_PERSCUSTINFO','T0202_IPDAT_PERSCUSTI0_H']
,['BF_PRD_PERSCUSTSOCIETYINFO','IP_个人客户社会信息表','IPDAT_PERSCUSTSOCIETYINFO','T0202_IPDAT_PERSCUSTS0_H']
,['BF_PRD_PRODUCT','PD_可售产品及目录表','PDDAT_PRODUCT','T0202_PDDAT_PRODUCT_H_371']
,['BF_CM_PRODCOMP','PD_产品映射表','PDDAT_PRODCOMP','T0202_PDDAT_PRODCOMP_0_C_371','1']

 ]


def main():
    df_0 = pd.read_excel(P9_Template_XLS_, sheetname=0, index_col=None)
    df_1 = pd.read_excel(P9_Template_XLS_, sheetname=1, index_col=None)
    df_2 = pd.read_excel(P9_Template_XLS_, sheetname=2, index_col=None)
    df_3_old = pd.read_excel(P9_Template_XLS_, sheetname=3, index_col=None)
    df_3 = pd.read_excel(P9_Template_XLS_, sheetname=3, index_col=None)
    df_4_old = pd.read_excel(P9_Template_XLS_, sheetname=4, index_col=None)
    df_4 = pd.read_excel(P9_Template_XLS_, sheetname=4, index_col=None)
    df_5_old = pd.read_excel(P9_Template_XLS_, sheetname=5, index_col=None)
    df_5 = pd.read_excel(P9_Template_XLS_, sheetname=5, index_col=None)
    df_6 = pd.read_excel(P9_Template_XLS_, sheetname=6, index_col=None)
    create_task_list(df_3, df_3_old)
    create_task_params(df_4, df_4_old)

    i = 2
    cols_list = []
    for item in df_5_old:
        cols_list.append(item)
    for list in lists:
        cols = {}
        j = 0
        for c in cols_list:
            cols[cols_list[j]] = df_5_old.loc[2][cols_list[j]]
            if j == 1 or j==0:#作业名  前置作业名
                tmp = df_5_old.loc[2][cols_list[j]]
                cols[cols_list[j]] = tmp.replace("_001", "_" + list[3])

            j = j + 1
        df_5.loc[i] = cols
        i = i + 1


    with pd.ExcelWriter(P9_Task_XLS) as writer:
        df_0.to_excel(writer, sheet_name='模板变更记录', index=None)
        df_1.to_excel(writer, sheet_name='1.作业流信息登记', index=None)
        df_2.to_excel(writer, sheet_name='2.作业流依赖信息登记', index=None)
        df_3.to_excel(writer, sheet_name='3.作业信息登记', index=None)
        df_4.to_excel(writer, sheet_name='4.作业参数登记', index=None)
        df_5.to_excel(writer, sheet_name='5.作业依赖关系登记', index=None)
        df_6.to_excel(writer, sheet_name='参数', index=None)


def create_task_params(df_4, df_4_old):
    i = 2
    cols_list = []
    for item in df_4_old:
        cols_list.append(item)
    for list in lists:
        for k in range(0, 10):
            cols = {}
            j = 0
            for c in cols_list:
                cols[cols_list[j]] = df_4_old.loc[2 + k][cols_list[j]]
                if j == 0:  # 作业名
                    tmp = df_4_old.loc[2 + k][cols_list[j]]
                    cols[cols_list[j]] = tmp.replace("_001", "_" + list[3])
                #if j == 14 and k == 0:  # 数据库访问控制ID
                #    cols[cols_list[j]] = "%s" % DbAccess_id
                if j == 14 and k == 1:  # 导出文件(全路径)
                    cols[cols_list[j]] = p2_outfile % list[3]
                if j == 14 and k == 2:  # 卸数目标表
                    cols[cols_list[j]] = "%s" % list[3]
                if (j == 14 and k == 3) :  # where_list 
                    #print(len(list))
                    if  len(list)== 5:
                        print( (list))                         
                        if list[4]=='1':                        
                            cols[cols_list[j]] = "%s" % " P9_data_date ='#par_date#'"  
                j = j + 1
            df_4.loc[i] = cols
            i = i + 1
        for k in range(0, 6):
            cols = {}
            j = 0
            for c in cols_list:
                cols[cols_list[j]] = df_4_old.loc[12 + k][cols_list[j]]
                if j == 0:
                    tmp = df_4_old.loc[12 + k][cols_list[j]]
                    cols[cols_list[j]] = tmp.replace("_001", "_" + list[3])

                if j == 14 and k == 0:  # 源数据文件全路径
                    cols[cols_list[j]] = p2_outfile % list[3]
                if j == 14 and k == 1:  # 目标数据文件全路径
                    cols[cols_list[j]] = b_tar_path % list[3]
                j = j + 1
            df_4.loc[i] = cols
            i = i + 1


def create_task_list(df_3, df_3_old):
    i = 2
    cols_list = []
    for item in df_3_old:
        cols_list.append(item)
    for list in lists:
        cols = {}
        j = 0
        for c in cols_list:
            cols[cols_list[j]] = df_3_old.loc[2][cols_list[j]]
            if j == 1:
                tmp = df_3_old.loc[2][cols_list[j]]
                cols[cols_list[j]] = tmp.replace("_001", "_" + list[3])

            j = j + 1
        df_3.loc[i] = cols
        i = i + 1

        cols = {}
        j = 0
        for c in cols_list:
            cols[cols_list[j]] = df_3_old.loc[3][cols_list[j]]
            if j == 1:
                tmp = df_3_old.loc[3][cols_list[j]]
                cols[cols_list[j]] = tmp.replace("_001", "_" + list[3])

            j = j + 1
        df_3.loc[i] = cols
        i = i + 1


if __name__ == "__main__":
    main()
# Out:
# ['BF_AGT_BILLPLAN', 'AR_账单计划', 'ARDAT_BILLPLAN', 'T0202_ARDAT_BILLPLAN_A_371', '1']
# ['BF_CM_PRODCOMP', 'PD_产品映射表', 'PDDAT_PRODCOMP', 'T0202_PDDAT_PRODCOMP_0_C_371', '1']

# %%
#PATH_HOME#/file/output/p9000/系统框架编号/110000000/data/#par_date#/P9000_
