# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
# pl 文件生成器 
lists =[['BF_AGT_LOAN_ARRANGEMENT','AR_借款合同基本信息表','ARDAT_LOANARRANGEMENT','T0202_ARDAT_LOANARRA_0_H','select * from APP_GDFHTS.T0202_ARDAT_LOANARRA_0_H_371']
,['BF_AGT_LOAN_AUTODEBIT','AR_借款合同委托扣款账户','ARDAT_AUTODEBIT','T0202_ARDAT_AUTODEBI_0_H','select * from APP_GDFHTS.T0202_ARDAT_AUTODEBI_0_H_371']
,['BF_AGT_COND_OF_CONTRACT','AR_借款合同条件信息','ARDAT_CONDOFCONTRACT','T0202_ARDAT_CONDOFCO_0_H','select * from APP_GDFHTS.T0202_ARDAT_CONDOFCO_0_H_371']
,['BF_AGT_CORP_ARRANGEMENT','AR_合作协议','ARDAT_CORPARRANGEMENT','T0202_ARDAT_CORPARRA_0_H','select * from APP_GDFHTS.T0202_ARDAT_CORPARRA_0_H_371']
,['BF_AGT_CORPFUND','AR_合作方协议补充信息','ARDAT_CORPFUND','T0202_ARDAT_CORPFUND_0_H','select * from APP_GDFHTS.T0202_ARDAT_CORPFUND_0_H_371']
,['BF_AGT_CORP_PROJECT','AR_合作项目','ARDAT_CORPPROJECT','T0202_ARDAT_CORPPROJ_0_H','select * from APP_GDFHTS.T0202_ARDAT_CORPPROJ_0_H_371']
,['BF_AGT_CREDIT_LOAN_ARRANGEMENT','AR_额度贷款合同基本信息表','ARDAT_CREDITLOANARRANGEMENT','T0202_ARDAT_CREDITLO_0_H','select * from APP_GDFHTS.T0202_ARDAT_CREDITLO_0_H_371']
,['BF_AGT_EVALUATEOF_RISK','AR_合约评价信息表_风险等级','ARDAT_EVALUATEOFRISK','T0202_ARDAT_EVALUATE_0_H','select * from APP_GDFHTS.T0202_ARDAT_EVALUATE_0_H_371']
,['BF_AGT_FUND_LOAN_COMPINFOREGI','AR_公积金贷款补充信息登记表','ARDAT_FUNDLOANCOMPINFOREGI','T0202_ARDAT_FUNDLOAN_0_H','select * from APP_GDFHTS.T0202_ARDAT_FUNDLOAN_0_H_371']
,['BF_AGT_GUARANTEE','AR_担保合同表','ARDAT_GUARANTEE','T0202_ARDAT_GUARANTE_0_H','select * from APP_GDFHTS.T0202_ARDAT_GUARANTE_0_H_371']
,['BF_AGT_LOAN_ACCT_INFO','AR_贷款账户信息','ARDAT_LOANACCTINFO','T0202_ARDAT_LOANACCT_0_H','select * from APP_GDFHTS.T0202_ARDAT_LOANACCT_0_H_371']
,['BF_AGT_MASTR_SLAVE_RELA','AR_主从合同对照表','ARDAT_MASTERSLAVERELA','T0202_ARDAT_MASTERSL_0_H','select * from APP_GDFHTS.T0202_ARDAT_MASTERSL_0_H_371']
,['BF_AGT_BILLPLAN','AR_账单计划','ARDAT_BILLPLAN','T0202_ARDAT_BILLPLAN_A','select * from APP_GDFHTS.T0202_ARDAT_BILLPLAN_A_371']
,['BF_AGT_STUDENT_LOAN','AR_助学贷款','ARDAT_STUDENTLOAN','T0202_ARDAT_STUDENTL_0_H','select * from APP_GDFHTS.T0202_ARDAT_STUDENTL_0_H_371']
,['BF_EVT_LOAN_FLOW_REGI','EV_贷款流程意见登记表','EVDAT_LOANFLOWREGI','T0202_EVDAT_LOANFLOW_1_H','select * from APP_GDFHTS.T0202_EVDAT_LOANFLOW_1_H_371']
,['BF_EVT_RISK_SORT_RESULT','EV_风险分类当前结果表','EVDAT_RISKSORTRESULT','T0202_EVDAT_RISKSORT_3_H','select * from APP_GDFHTS.T0202_EVDAT_RISKSORT_3_H_371']
,['BF_CM_ADDRESS_INFO','LO_地址信息主表','LODAT_ADDRESSINFO','T0202_LODAT_ADDRESSI_0_H','select * from APP_GDFHTS.T0202_LODAT_ADDRESSI_0_H']
,['BF_AST_ACCT_INFO','RI_银行存款','RIDAT_ACCTINFO','T0202_RIDAT_ACCTINFO_0_H','select * from APP_GDFHTS.T0202_RIDAT_ACCTINFO_0_H']
,['BF_AST_BUIL_BASE_INFO','RI_楼盘基本信息','RIDAT_BUILBASEINFO','T0202_RIDAT_BUILBASE_0_H','select * from APP_GDFHTS.T0202_RIDAT_BUILBASE_0_H_371']
,['BF_AST_BUIL_PROJ_INFO','RI_楼盘项目信息','RIDAT_BUILPROJINFO','T0202_RIDAT_BUILPROJ_0_H','select * from APP_GDFHTS.T0202_RIDAT_BUILPROJ_0_H_371']
,['BF_AST_HOUSE_BASE_INFO','RI_房屋基本信息表','RIDAT_HOUSEBASEINFO','T0202_RIDAT_HOUSEBAS_0_H','select * from APP_GDFHTS.T0202_RIDAT_HOUSEBAS_0_H']
,['BF_AST_RIINFOMAIN','RI_资源信息主表','RIDAT_RIINFOMAIN','T0202_RIDAT_RIINFOMA_0_H','select * from APP_GDFHTS.T0202_RIDAT_RIINFOMA_0_H_371']
,['BF_PR_NPLPM_CUST_INFO','IP_客户信息主表','IPDAT_CUSTINFO','T0202_IPDAT_CUSTINFO_H','select * from APP_GDFHTS.T0202_IPDAT_CUSTINFO_H']
,['BF_PRD_CUSTADDRINFO','IP_客户与地址关系表','IPDAT_CUSTADDRINFO','T0202_IPDAT_CUSTADDRI0_H','select * from APP_GDFHTS.T0202_IPDAT_CUSTADDRI0_H']
,['BF_PRD_PERSCUSTINFO','IP_个人客户基本信息表','IPDAT_PERSCUSTINFO','T0202_IPDAT_PERSCUSTI0_H','select * from APP_GDFHTS.T0202_IPDAT_PERSCUSTI0_H']
,['BF_PRD_PERSCUSTSOCIETYINFO','IP_个人客户社会信息表','IPDAT_PERSCUSTSOCIETYINFO','T0202_IPDAT_PERSCUSTS0_H','select * from APP_GDFHTS.T0202_IPDAT_PERSCUSTS0_H']
,['BF_PRD_PRODUCT','PD_可售产品及目录表','PDDAT_PRODUCT','T0202_PDDAT_PRODUCT_H','select * from APP_GDFHTS.T0202_PDDAT_PRODUCT_H_371']
,['BF_CM_PRODCOMP','PD_产品映射表','PDDAT_PRODCOMP','T0202_PDDAT_PRODCOMP_0_C','select * from APP_GDFHTS.T0202_PDDAT_PRODCOMP_0_C_371']
 ]
filename='E:\\资料\\个贷配套改造项目\\perljob\\a0202\\fhts\\371\\runall_database.sql' 
runall = open(filename, "w")
for list in (lists):
    
    para=list[0]
    filename='E:\\资料\\个贷配套改造项目\\perljob\\a0202\\fhts\\371\\perl\\fhts_371_%s.pl'
    filename=filename % (para.lower())
    print(filename)
    # 打开一个文件


    fo = open(filename, "w")

    tmp="""
    #***************************************************************************************************
    # GP script in Perl, generate by Script Wizard
    #
    # 注意，本模板适用于P9平台的任务控制台调用 
    #
    # 任 务 名: 用于配置控制台的任务名,必须按规范命名 
    # 目 标 表: 
    #    ${ADWADTANG}.app_table_1
    # 源 表 名: 
    #    ${ADWADTANG}.app_table_2
    # 加载策略: [00] (注,00:其他 01:覆盖,02:更新,03:追加,04:拉链)
    # 运行周期: 4 (注, 1:天,2:星期,3:旬,4:月,5:季,6:半年,7:年，00:其他)
    # 脚本功能: 
    # 创建时间: 2017-10-9 
    # 文 件 名: demo.pl
    # 作    者: 
    # 修改记录: 
    #***************************************************************************************************

    use strict; # Declare using Perl strict syntax
    use File::Basename;
    use Cwd 'abs_path';
    use Time::Local;

    require($ENV{"HOME"}."/bin/etl_base_function.pm");

    #
    # If you are using other Perls package, declare here
    #


    # Variable Section
    # login variable
    #变量定义
    #此定义变量是读取控制台配置数据库连接accessi_id，由中心统一配置,是第一传入参数 
    #这些变量值是由函数ETL_BASE::get_logon_info($p_db_access_id)产生
    #$prefixion 数据库schames，开发需要用到,分行odsb项目的schames是app_gdfhtssor 
    my ($ret_logon,$db_type,$prefixion,$db_name,$db_usr,$db_pwd,$logon_str,$conn_str);


    #此定义变量是自定义传入参数，在控制台上配置,可自行添加需要传入参数
    #此变量值获取见脚本开始处
    #$TXNDATE 是工作日期，有日期函数可用，是第二传入参数
    #$BATCH 是任务批次，可在控制台定义，是第三传入参数
    #后续传入参数可自定义
    my ($TXNDATE, $BATCH, $today);
    my ($PRONUM,$MAXID,$MINID,$OFFSET);

    my $SCRIPT = basename("$0");

    #自定变量
    #my ( $a1,$a2 );


    #--------------------------------------------------------------------
    #脚本调用存储过程
    # PSQL function
    sub run_psql_command
    {
        my $rc = open(PSQL, "|".$logon_str);

        # To see if psql command invoke ok?
        unless ($rc) {
            print "Could not invoke PSQL command\n";
            return -1;
        }

        ### Below are PSQL scripts ###
    print PSQL <<ENDOFINPUT;

    \\encoding UTF8;
    \\timing on;
    set gp_autostats_mode=none ;

    BEGIN;

      --调用存储过程,app_demp_plsql()见文件app_demo.sql
      SELECT $prefixion.fhts_371_get_%s( '$PRONUM','$MAXID','$MINID','$OFFSET'   ) ;

    END;

    ENDOFINPUT

    ### End of PSQL scripts ###
    close(PSQL);

        my $RET_CODE = $? >> 8;

        # if the return code is no zero, that means something error happen
        # so we return 1, otherwise, we return 0 means ok
        if ( $RET_CODE != 0 ) {
            return -1;
        }
        else {
            return 0;
        }
    }

    #--------------------------------------------------------------------
    # main function
    sub main
    {
        my $ret;    #config the env

        # Call psql command to load data
        $ret = run_psql_command();

        print "run_psql_command() = $ret \n";
        return $ret;
    }

    #--------------------------------------------------------------------
    # program section

    # To see if there is one parameter,
    # if there is no parameter, exit program
    if ( $#ARGV < 0 ) {
        print "Usage: ".basename($0)."  Control_File \n";
        print "          Control_File: dir.jobnameYYYYMMDD (or sysname_jobname_YYYYMMDD.dir)\n";
        exit(1);
    }



    #perl脚本开始

    # Get the command argument
    my $p_db_access_id = $ARGV[0];
    $TXNDATE = $ARGV[1];
    $BATCH = $ARGV[2];
    $PRONUM = $ARGV[3];
    $MINID = $ARGV[4];
    $MAXID = $ARGV[5];
    $OFFSET = $ARGV[6];

    if ( !defined($PRONUM) ){ 
        print "Usage: ".basename($0)."  Control_File \n";
        print "          Control_File: MINID IS NULL \n";
        exit(1);
    }

    ($ret_logon,$db_type,$prefixion,$db_name,$db_usr,$db_pwd,$logon_str,$conn_str) = ETL_BASE::get_logon_info($p_db_access_id);
    if( $ret_logon != 0) {
         print "[ERROR] 获取目标数据库信息失败\n";
         return -1;
    }
    print "\n[Info] DB INFO:"
          ."\n logon_str - $logon_str"
          ."\n conn_str  - $conn_str"
          ."\n db_usr     - $db_usr"
          ."\n db_pwd     - $db_pwd"
          ."\n db_type    - $db_type"
          ."\n prefixion - $prefixion"
          ."\n";

    $ENV{"PGPASSWORD"} = $db_pwd;

    if ($TXNDATE =~/[0-9]{8}($|\.)/) {
        $TXNDATE = substr($&,0,8);
        $today = substr($TXNDATE, 2, 6);
        $TXNDATE = substr($TXNDATE, 0, 4)."-".substr($TXNDATE, 4, 2)."-".substr($TXNDATE, 6, 2);
    }
    else{
        print "TXNDATE: Date format Error!\n";
        exit(-1);
    }

    open(STDERR, ">&STDOUT");

    my $ret = main();

    exit($ret); 



    """
    fo.write(tmp % list[3].lower() );

    # 关闭打开的文件
    fo.close() 
    
    tmp_fnc='''
    /*-----------------------------------------------------------------------------------
	#创建时间：2017-10-15
	#创建人  ：
	#功能描述: 创建存储过程 %s
	#传入参数说明
	   p_pro         分段处理使用,
	   p_maxid       分段处理使用,
	   p_minid       分段处理使用,
	   p_offset      分段处理使用,
	#返回参数: 
	#修改时间：2016-07-19
	#修改内容:
	#修改人：
------------------------------------------------------------------------------------*/
DROP FUNCTION IF EXISTS app_gdfhts.fhts_371_get_%s( p_pro VARCHAR, p_maxid VARCHAR, p_minid VARCHAR,p_offset VARCHAR ); 
CREATE OR REPLACE FUNCTION app_gdfhts.fhts_371_get_%s( p_pro VARCHAR, p_maxid VARCHAR, p_minid VARCHAR,p_offset VARCHAR ) 
RETURNS INTEGER AS $BODY$
DECLARE
	v_sqlstr     VARCHAR(2000) DEFAULT ''; 
  v_partition  VARCHAR(200)  DEFAULT '';
  v_mon_dif    integer ;
  v_date       VARCHAR(8);
  v_last_13mon VARCHAR(6);
  v_len        integer;
begin 

  RAISE NOTICE 'demo func begin';


--插入表
  RAISE NOTICE 'select  table app_gdfhts.%s';
  v_sqlstr := '%s 
      ;';
  
  RAISE NOTICE 'v_sqlstr=[%%]',v_sqlstr;
  EXECUTE v_sqlstr;
  

  RAISE NOTICE ' app_gdfhtssor.fhts_371_get_%s func end';
  RETURN 0;
  
END;
$BODY$ language 'plpgsql';

    
    '''
    filename='E:\\资料\\个贷配套改造项目\\perljob\\a0202\\fhts\\371\\func\\create_func_fhts_371_%s_hantongchao_20180301.sql'
    filename=filename % (para.lower())
    
  
    runall.write('\\i ./func/create_func_fhts_371_%s_hantongchao_20180301.sql\n' % (para.lower()))
     
    fo = open(filename, "w")
    
    if len(list)==5:
        print(list,len(list))
        fo.write(tmp_fnc % (list[1],list[3].lower(),para.lower(),list[3].lower(),list[4].lower(),para.lower()) );
    else:
        fo.write(tmp_fnc % (list[1],para.lower(),para.lower(),list[3].lower(),'select * from  app_gdfhtssor.'+list[3].lower(),para.lower()) );

    # 关闭打开的文件
    fo.close()
    
    # shell 
    para=list[0]
    filename='E:\\资料\\个贷配套改造项目\\perljob\\a0202\\fhts\\371\\shell\\fhts_371_%s.sh'
    filename=filename % (para.lower())
    
    # 打开一个文件
    tmpshell='''
    ##--创建表
#psql -h 128.196.116.70 -p 5432 -U app_gdfhts -d acadb_vt -f ./create_table_demo.sql

##--创建存储过程
#psql -h 128.196.116.70 -p 5432 -U app_gdfhts -d acadb_vt -f ./create_fnc_demo.sql


##--执行perl脚本
##--注: access_id由中心统一配置，用于数据库连接
##--app_gdfhts_pl1 数据库acadb_pl1
##--app_gdfhts_pl2 数据库acadb_pl2
##--app_gdfhts_pl3 数据库acadb_pl3
##--app_gdfhts_pl4 数据库acadb_pl4
##--app_gdfhts_vt 数据库acadb_vt
##--脚本调用方式为 perl demo.pl access_id 日期YYYYMMDD 批次(可选) 参数1 参数2 ...

perl /home/ap/dip/szetl/appjob/perljob/a0202/fhts/371/per/fhts_371_%s.pl app_gdfhts_vt 20170915 1 AAA 1000 100 bbb 

    ''' 

    fo = open(filename, "w")
    fo.write(tmpshell % para.lower())
    fo.close()
runall.close()
# Out:
# E:\资料\个贷配套改造项目\perljob\a0202\fhts\371\perl\fhts_371_bf_agt_loan_arrangement.pl
# ['BF_AGT_LOAN_ARRANGEMENT', 'AR_借款合同基本信息表', 'ARDAT_LOANARRANGEMENT', 'T0202_ARDAT_LOANARRA_0_H', 'select * from APP_GDFHTS.T0202_ARDAT_LOANARRA_0_H_371'] 5
# E:\资料\个贷配套改造项目\perljob\a0202\fhts\371\perl\fhts_371_bf_agt_loan_autodebit.pl
# ['BF_AGT_LOAN_AUTODEBIT', 'AR_借款合同委托扣款账户', 'ARDAT_AUTODEBIT', 'T0202_ARDAT_AUTODEBI_0_H', 'select * from APP_GDFHTS.T0202_ARDAT_AUTODEBI_0_H_371'] 5
# E:\资料\个贷配套改造项目\perljob\a0202\fhts\371\perl\fhts_371_bf_agt_cond_of_contract.pl
# ['BF_AGT_COND_OF_CONTRACT', 'AR_借款合同条件信息', 'ARDAT_CONDOFCONTRACT', 'T0202_ARDAT_CONDOFCO_0_H', 'select * from APP_GDFHTS.T0202_ARDAT_CONDOFCO_0_H_371'] 5
# E:\资料\个贷配套改造项目\perljob\a0202\fhts\371\perl\fhts_371_bf_agt_corp_arrangement.pl
# ['BF_AGT_CORP_ARRANGEMENT', 'AR_合作协议', 'ARDAT_CORPARRANGEMENT', 'T0202_ARDAT_CORPARRA_0_H', 'select * from APP_GDFHTS.T0202_ARDAT_CORPARRA_0_H_371'] 5
# ...

# %%
 P9 PL2已添加N1QDOD。以下是P9-PL2 NFT信息：
bdenodeman.sh -view  

PL2环境（集群）
显示集群参数，节点：[G126]
     instance ip      ftpprot  cmdport  csspport
------------------------------------------------
01   128.196.100.10    13087    13088    13089  
02   128.196.100.11    13087    13088    13089  
03   128.196.100.1     13087    13088    13089  
04   128.196.100.2     13087    13088    13089  

G126是集群，配01节点后执行clusterinfo.sh -d G126，
再执行bdenodecache.sh nodeinfo，刷新缓存信息。

若之前添加过G126节点，需要更换IP或者端口，重新添加对方节点后，绿灯不通----此为BDE缓存问题，需执行以下步骤：
1、用bdenodeman.sh view 查看G126节点信息
2、到$HOME/cluster目录下查看*G126.properties 的IP是否与 步骤一的信息一致，如果不一致，则进行修改
3、执行clusterinfo.sh -r G126，如果展现的IP地址是与步骤1一致，则选择Y ，刷新IP与步骤1的一致
4、执行clusterinfo.sh -d G126，如果展现的IP地址是与步骤1一致，则选择Y，刷新IP与步骤1的一致
5、执行bdenodecache.sh nodeinfo，刷新缓存信息
6、执行tasktest.sh -n G126测试绿灯
7、如果还是不通，可尝试重启服务
（如果对方节点是集群模式，则除了步骤1,2，每个节点都执行一遍以上操作）
如果对方是集群，则P9节点也要按照以上步骤操作

# %%
asyntrans -s /home/ap/dip/file/output/p9000/AB371/371000000/data/20171218/P9000_SAFEID_371000000_T0202_ARDAT_FUNDLOAN_0_H_371_ADD_20171218_0001.dat -t /home/ap/dip/file/input/AB371/371000000/data/20171218/P9000_SAFEID_371000000_T0202_ARDAT_FUNDLOAN_0_H_371_ADD_20171218_0001.dat -r 1 -i N1QDOD -m 0 -a RPTMID
